# %% [markdown]
# <a href="https://colab.research.google.com/github/roobesh1805hub/DAA-Lab-exercises/blob/main/DAA_lab_exercise_3B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class DisjointSet:

    def __init__(self, vertices):
        self.parent = {v: v for v in vertices}

    def find(self, item):
        if self.parent[item] == item:
            return item
        self.parent[item] = self.find(self.parent[item])
        return self.parent[item]

    def union(self, x, y):
        self.parent[self.find(x)] = self.find(y)


vertices = ['A','B','C','D','E','F']

edges = [
('A','B',4),
('A','C',2),
('B','C',5),
('B','D',10),
('C','E',3),
('D','E',7),
('D','F',8),
('E','F',6)
]

edges.sort(key=lambda x: x[2])

ds = DisjointSet(vertices)

mst = []
cost = 0

for u, v, w in edges:

    if ds.find(u) != ds.find(v):

        ds.union(u, v)

        mst.append((u, v, w))

        cost += w

print("Minimum Spanning Tree")

for edge in mst:
    print(edge)

print("Total Cost =", cost)
# Out:
# Minimum Spanning Tree
# ('A', 'C', 2)
# ('C', 'E', 3)
# ('A', 'B', 4)
# ('E', 'F', 6)
# ('D', 'E', 7)
# Total Cost = 22
