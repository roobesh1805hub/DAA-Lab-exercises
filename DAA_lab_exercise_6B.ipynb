# %% [markdown]
# <a href="https://colab.research.google.com/github/roobesh1805hub/DAA-Lab-exercises/blob/main/DAA_lab_exercise_6B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def matrix_chain_order(dims):
    n = len(dims) - 1

    m = [[0] * (n + 1) for _ in range(n + 1)]
    s = [[0] * (n + 1) for _ in range(n + 1)]

    for l in range(2, n + 1):
        for i in range(1, n - l + 2):
            j = i + l - 1
            m[i][j] = float('inf')

            for k in range(i, j):
                cost = (
                    m[i][k]
                    + m[k + 1][j]
                    + dims[i - 1] * dims[k] * dims[j]
                )

                if cost < m[i][j]:
                    m[i][j] = cost
                    s[i][j] = k

    return m, s


def print_optimal_parens(s, i, j):
    if i == j:
        return f"M{i}"

    k = s[i][j]
    left = print_optimal_parens(s, i, k)
    right = print_optimal_parens(s, k + 1, j)

    return f"({left} x {right})"


# Graphics Pipeline
# T(4x4), R(4x4), S(4x4), V(4x10000), P(10000x1)

dims = [4, 4, 4, 4, 10000, 1]

m, s = matrix_chain_order(dims)
n = len(dims) - 1

print("Graphics Pipeline Matrices:")
print("M1 = T (4x4)")
print("M2 = R (4x4)")
print("M3 = S (4x4)")
print("M4 = V (4x10000)")
print("M5 = P (10000x1)")

print("\nMinimum Scalar Multiplications:", m[1][n])
print("Optimal Parenthesization:", print_optimal_parens(s, 1, n))
# Out:
# Graphics Pipeline Matrices:
# M1 = T (4x4)
# M2 = R (4x4)
# M3 = S (4x4)
# M4 = V (4x10000)
# M5 = P (10000x1)
#
# Minimum Scalar Multiplications: 40048
# Optimal Parenthesization: (M1 x (M2 x (M3 x (M4 x M5))))
