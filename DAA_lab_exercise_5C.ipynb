# %% [markdown]
# <a href="https://colab.research.google.com/github/roobesh1805hub/DAA-Lab-exercises/blob/main/DAA_lab_exercise_5C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

def partition(arr, low, high):
    pivot = arr[high]
    i = low

    for j in range(low, high):
        if arr[j] <= pivot:
            arr[i], arr[j] = arr[j], arr[i]
            i += 1

    arr[i], arr[high] = arr[high], arr[i]
    return i


def quickselect(arr, low, high, k):
    if low == high:
        return arr[low]

    pivot_index = partition(arr, low, high)

    if pivot_index == k:
        return arr[pivot_index]
    elif k < pivot_index:
        return quickselect(arr, low, pivot_index - 1, k)
    else:
        return quickselect(arr, pivot_index + 1, high, k)


# Driver Code
n = 1000
arr = [random.randint(1, 10000) for _ in range(n)]

# k = 1 (Minimum)
arr1 = arr.copy()
minimum = quickselect(arr1, 0, n - 1, 0)

# k = n (Maximum)
arr2 = arr.copy()
maximum = quickselect(arr2, 0, n - 1, n - 1)

# k = n//2 (Median)
arr3 = arr.copy()
median = quickselect(arr3, 0, n - 1, n // 2)

print("Array Size:", n)
print("Minimum Element:", minimum)
print("Maximum Element:", maximum)
print("Median Element:", median)
# Out:
# Array Size: 1000
# Minimum Element: 4
# Maximum Element: 9988
# Median Element: 4826
